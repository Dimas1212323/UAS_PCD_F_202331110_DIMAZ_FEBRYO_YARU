# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Baca gambar dan ubah ke grayscale

# %%
img = cv2.imread('foto_diri_tepi.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ### Deteksi tepi pakai Canny

# %%
edges = cv2.Canny(gray, 100, 200)

# %% [markdown]
# ### Temukan kontur dari hasil tepi

# %%
contours, _ = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img_contours = img.copy()
cv2.drawContours(img_contours, contours, -1, (0, 255, 0), 2)
# Out:
# array([[[225, 209, 196],
#         [225, 209, 196],
#         [225, 209, 196],
#         ...,
#         [ 78,  71,  62],
#         [ 78,  71,  62],
#         [ 78,  71,  62]],
#
#        [[225, 209, 196],
#         [225, 209, 196],
#         [225, 209, 196],
#         ...,
#         [ 78,  71,  62],
#         [ 78,  71,  62],
#         [ 78,  71,  62]],
#
#        [[225, 209, 196],
#         [225, 209, 196],
#         [225, 209, 196],
#         ...,
#         [ 78,  71,  62],
#         [ 78,  71,  62],
#         [ 78,  71,  62]],
#
#        ...,
#
#        [[124, 137, 135],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [165, 176, 180],
#         [133, 144, 148]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
# ...

# %% [markdown]
# ### Tampilkan gambar asli, tepi, dan kontur

# %%
titles = ['Original Image', 'Canny Edge Detection', 'Contours Detection']
images = [img, edges, img_contours]

plt.figure(figsize=(15, 5))

# %%
for i in range(3):
    plt.subplot(1, 3, i + 1)
    # Convert BGR ke RGB jika bukan grayscale
    if len(images[i].shape) == 3:
        plt.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))
    else:
        plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()
